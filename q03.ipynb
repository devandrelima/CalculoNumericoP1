# %%
# Questão 3
import math
import time 

# Função
def f(x):
    return x ** 4+2*x**2-5

# Calculo de interações
def calcK(a, b, epsilon):
    return math.ceil(math.log2((abs(b-a))/epsilon))

# Método da bissecção
def bisseccao(a, b, epsilon, k):
    time.sleep(1)
    iter_count = 0
    # Para intervalos com f(a) e f(b) com o mesmo sinal
    if f(a) * f(b) >= 0:
        while abs(b - a) > epsilon:
            x = (a + b) / 2 # Calculo do ponto médio
            FX = f(x) # Calculo de f(x)
            FA = f(a) # Calculo de f(a)
            FB = f(b) # Calculo de f(b)
            # Verificando se os valores no intervalo são menores que epsilon e consequentemente a raiz
            print(f"Iteração {iter_count}: x = {x}, f(x) = {f(x)}")
            if abs(FA) < epsilon:
                return a
            elif abs(FB) < epsilon:
                return b
            # Verificando se o valor de f(x) é menor que epsilon e consequentemente a raiz
            elif abs(FX) < epsilon:
                return x
            # Escolha do intervalo
            elif FB > FA:
                b = x # Se f(b) for maior que f(a) então o intervalo é [a, x]
            else:
                a = x # Se f(a) for maior que f(b) então o intervalo é [x, b]
            iter_count += 1
            if iter_count > k: # Se o número de iterações for maior que k, então não foi possível encontrar a raiz
                return None
    else:
        # Para intervalos com f(a) e f(b) opostos
        while abs(b - a) > epsilon:
            x = (a + b) / 2
            if f(x) == 0:
                return x
            elif f(a) * f(x) < 0:
                b = x
            else:
                a = x
            iter_count += 1
            print(f"Iteração {iter_count}: x = {x}, f(x) = {f(x)}")
        return x

# Entrada de dados
a = float(input("Digite o valor de a: "))
b = float(input("Digite o valor de b: "))
epsilon = float(input("Digite o valor de epsilon: "))
 

k = calcK(a, b, epsilon)

inicio = time.time()

raiz = bisseccao(a, b, epsilon, k)

tempo_total = time.time() - inicio
tempo_total -= 1

print(f"Iterações: {iter_count}")
print(f"k máximo: {k}")
print(f"Tempo (segundos): {tempo_total}")

if raiz is not None:
    print(f"A raiz aproximada é: {raiz:.5f}.")
else:
    print(f"Não foi possível encontrar a raiz com os parâmetros fornecidos.")
# Out:
# Iteração 1: x = -1.5, f(x) = 4.5625
# Iteração 2: x = -0.25, f(x) = -4.87109375
# Iteração 3: x = -0.875, f(x) = -2.882568359375
# Iteração 4: x = -1.1875, f(x) = -0.1911468505859375
# Iteração 5: x = -1.34375, f(x) = 1.871750831604004
# Iteração 6: x = -1.265625, f(x) = 0.7693977952003479
# Iteração 7: x = -1.2265625, f(x) = 0.2722976841032505
# Iteração 8: x = -1.20703125, f(x) = 0.03647769638337195
# Iteração 9: x = -1.197265625, f(x) = -0.07834554485452827
# Iteração 10: x = -1.2021484375, f(x) = -0.02118834043994866
# Iteração 11: x = -1.20458984375, f(x) = 0.007580863891291756
# Iteração 12: x = -1.203369140625, f(x) = -0.006819665507460826
# Iteração 13: x = -1.2039794921875, f(x) = 0.0003766140998422429
# Iterações: 11
# k máximo: 13
# Tempo (segundos): 0.0009903907775878906
# A raiz aproximada é: -1.20398.

# %%
## Q3
#####
import math
import time 

# Função
def f(x):
    return x * 3 + 2(x**2) - 5

# Calculo de interações
def calcK(a, b, epsilon):
    return math.ceil(math.log2((abs(b-a))/epsilon))
  
iter_count = 0

# Método da bissecção
def bisseccao(a, b, epsilon, k):
    global iter_count
    # Para intervalos com f(a) e f(b) com o mesmo sinal
    while iter_count < k:
        
        x = (a + b) / 2 # Calculo do ponto médio

        print(x,"----",f(x) )

        FX = f(x) # Calculo de f(x)
        FA = f(a) # Calculo de f(a)
        FB = f(b) # Calculo de f(b)
        
        # Verificando se os valores no intervalo são menores que epsilon e consequentemente a raiz
        if abs(FA) < epsilon:
            return a
        elif abs(FB) < epsilon:
            return b
        # Verificando se o valor de f(x) é menor que epsilon e consequentemente a raiz
        elif abs(FX) < epsilon:
            return x
        # Escolha do intervalo
        elif FX * FA < 0:
            b = x # Se f(b) for maior que f(a) então o intervalo é [a, x]
        else:
            a = x # Se f(a) for maior que f(b) então o intervalo é [x, b]

        iter_count += 1

# Entrada de dados
a = float(input("Digite o valor de a: "))
b = float(input("Digite o valor de b: "))
epsilon = 0.001
k = calcK(a, b, epsilon) 

inicio = time.time() 
raiz = bisseccao(a, b, epsilon, k)
tempo_total = time.time() - inicio

print(f"Iterações: {iter_count}")
print(f"k: {k}")
print(f"Tempo (segundos): {tempo_total}")

if raiz is not None:
    print(f"A raiz aproximada é: {raiz:.5f}.")
else:
    print(f"Não foi possível encontrar a raiz com os parâmetros fornecidos.")
