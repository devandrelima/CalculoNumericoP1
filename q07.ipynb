# %%
import time

def f(x):
    return x**3 - 9*x + 3

def derivada(x, epsilon):
    return (f(x + epsilon) - f(x)) / epsilon

def metodo_newton(x0, epsilon, max_iter=100):
    x = x0
    iter_count = 0
    print("------------------- Método de Newton -------------------")
    while abs(f(x)) > epsilon and iter_count < max_iter:
        df = derivada(x, epsilon)
        if df == 0:
            raise ValueError("A derivada é zero. O método de Newton pode falhar.")

        x = x - f(x) / df
        iter_count += 1
        print(f"Iteração {iter_count}: x = {x}, f(x) = {f(x)}")

        if iter_count == max_iter:
            return None
    return x
def metodo_secante(x0, x1, epsilon, max_iter=100):

    iter_count = 0
    print("------------------- Método da Secante -------------------")
    while abs(f(x1)) > epsilon and iter_count < max_iter:
        if f(x1) == f(x0):
            raise ValueError("Divisão por zero na iteração. Método falhou.")

        # Fórmula do método da secante
        x_new = x1 - f(x1) * (x1 - x0) / (f(x1) - f(x0))

        # Atualizar os pontos
        x0, x1 = x1, x_new
        iter_count += 1
        print(f"Iteração {iter_count}: x = {x1}, f(x) = {f(x1)}")

    if iter_count == max_iter:
        print("Número máximo de iterações atingido.")
        return None

    return x1


# Entrada do usuário
x0 = float(input("Digite o ponto inicial (Newton/Secante): "))
x1 = float(input("Digite o segundo ponto inicial (x1) (Secante): "))
epsilon = float(input("Digite o valor da precisão (Newton/Secante): "))

# Encontrando a raiz
inicioN = time.time()
raizN = metodo_newton(x0, epsilon)
fimN = time.time()

inicioS = time.time()
raizS = metodo_secante(x0, x1, epsilon)
fimS = time.time()

if raizN and raizS is not None: 
    print(f"Raiz Newton: {raizN} em {fimN - inicioN:.5f} segundos.\nRaiz Secante: {raizS} em {fimS - inicioS:.5f} segundos.")
else:
    print(f"O código de Newton executou em {fimN - inicioN:.5f} segundos, mas não foi possível encontrar a raiz com os parâmetros fornecidos.")
# Out:
# ------------------- Método de Newton -------------------
# Iteração 1: x = 3.742710009199751, f(x) = 21.74303591251372
# Iteração 2: x = 3.0845254904257864, f(x) = 4.5863637517634
# Iteração 3: x = 2.849954640837691, f(x) = 0.4984279606643476
# Iteração 4: x = 2.8175371424020796, f(x) = 0.009228132704752312
# Iteração 5: x = 2.8169146294133975, f(x) = 8.537818125375907e-06
# ------------------- Método da Secante -------------------
# Iteração 1: x = 3.9878048780487805, f(x) = 30.526173082224574
# Iteração 2: x = 3.5310273922303006, f(x) = 15.24614834465288
# Iteração 3: x = 3.0752625993787377, f(x) = 4.406133240502747
# Iteração 4: x = 2.8900082077252343, f(x) = 1.1277007862827482
# Iteração 5: x = 2.8262852163117382, f(x) = 0.1394831674445527
# Iteração 6: x = 2.8172909578488645, f(x) = 0.005581286244062511
# Iteração 7: x = 2.816916059971521, f(x) = 2.9717282895802555e-05
# Raiz Newton: 2.8169146294133975 em 0.00047 segundos.
# Raiz Secante: 2.816916059971521 em 0.00000 segundos.
