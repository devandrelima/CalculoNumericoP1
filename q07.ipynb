# %%
import time

def f(x):
    return (x+1)**2

def derivada(x, epsilon):
    return (f(x + epsilon) - f(x)) / epsilon

def metodo_newton(x0, epsilon, max_iter=100):
    time.sleep(1)
    x = x0
    iter_count = 0
    print("------------------- Método de Newton -------------------")
    while abs(f(x)) > epsilon and iter_count < max_iter:
        df = derivada(x, epsilon)
        if df == 0:
            raise ValueError("A derivada é zero. O método de Newton pode falhar.")

        x = x - f(x) / df
        iter_count += 1
        print(f"Iteração {iter_count}: x = {x}, f(x) = {f(x)}")

        if iter_count == max_iter:
            return None
    return x

def metodo_secante(x0, x1, epsilon, max_iter=100):
    time.sleep(1)

    iter_count = 0
    print("------------------- Método da Secante -------------------")
    while abs(f(x1)) > epsilon and iter_count < max_iter:
        if f(x1) == f(x0):
            raise ValueError("Divisão por zero na iteração. Método falhou.")

        # Fórmula do método da secante
        x_new = x1 - f(x1) * (x1 - x0) / (f(x1) - f(x0))

        # Atualizar os pontos
        x0, x1 = x1, x_new
        iter_count += 1
        print(f"Iteração {iter_count}: x = {x1}, f(x) = {f(x1)}")

    if iter_count == max_iter:
        print("Número máximo de iterações atingido.")
        return None

    return x1

# Entrada do usuário
x0 = float(input("Digite o ponto inicial (Newton/Secante): "))
x1 = float(input("Digite o segundo ponto inicial (x1) (Secante): "))
epsilon = float(input("Digite o valor da precisão (Newton/Secante): "))

# Encontrando a raiz
inicioN = time.time()
raizN = metodo_newton(x0, epsilon)
fimN = time.time() - 1

inicioS = time.time()
raizS = metodo_secante(x0, x1, epsilon)
fimS = time.time() - 1

if raizN and raizS is not None: 
    print(f"Raiz Newton: {raizN} em {(fimN - inicioN):.5f} segundos.\nRaiz Secante: {raizS} em {(fimS - inicioS):.5f} segundos.")
else:
    print(f"O código de Newton executou em {(fimN - inicioN):.5f} segundos, mas não foi possível encontrar a raiz com os parâmetros fornecidos.")
# Out:
# ------------------- Método de Newton -------------------
# Iteração 1: x = -0.4999750012501445, f(x) = 0.250024999374793
# Iteração 2: x = -0.7499625031246585, f(x) = 0.06251874984368641
# Iteração 3: x = -0.8749562565606142, f(x) = 0.01563593777333495
# Iteração 4: x = -0.9374531382728217, f(x) = 0.003912109911918758
# Iteração 5: x = -0.9687015891054653, f(x) = 0.0009795905245231263
# Iteração 6: x = -0.984325834427164, f(x) = 0.0002456794664046761
# Iteração 7: x = -0.9921379967090571, f(x) = 6.181109574679678e-05
# ------------------- Método da Secante -------------------
# Iteração 1: x = 0.5, f(x) = 2.25
# Iteração 2: x = 2.0, f(x) = 9.0
# Iteração 3: x = 0.0, f(x) = 1.0
# Iteração 4: x = -0.25, f(x) = 0.5625
# Iteração 5: x = -0.5714285714285714, f(x) = 0.18367346938775514
# Iteração 6: x = -0.7272727272727273, f(x) = 0.07438016528925619
# Iteração 7: x = -0.8333333333333334, f(x) = 0.027777777777777766
# Iteração 8: x = -0.896551724137931, f(x) = 0.010701545778834717
# Iteração 9: x = -0.9361702127659575, f(x) = 0.004074241738343139
# Iteração 10: x = -0.9605263157894737, f(x) = 0.0015581717451523555
# Iteração 11: x = -0.975609756097561, f(x) = 0.000594883997620465
# Iteração 12: x = -0.9849246231155778, f(x) = 0.00022726698820737048
# Iteração 13: x = -0.9906832298136645, f(x) = 8.680220670498959e-05
# Raiz Newton: -0.9921379967090571 em 0.00117 segundos.
# Raiz Secante: -0.9906832298136645 em 0.00084 segundos.
